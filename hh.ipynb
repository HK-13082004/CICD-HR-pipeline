# %%
print("Hello")
# Out:
# Hello

# %%
lst=[10,45,67,34,88]

result=[]
for i in lst:
    if i%2==0:
        result.append(i)

# %%
lst=[10,45,67,34,88]

result=[]
for i in lst:
    if i%2==0:
        result.append(i)

# %%
a = "HEMANT KUMAR"
for i in a:
    print(i)
